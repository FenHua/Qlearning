# %%
from __future__ import print_function
import copy
MAP= \
 '''
.........
.       .
.     o .
.       .
.........
'''
MAP=MAP.strip().split('\n')
MAP=[[c for c in line] for line in MAP]
DX=[-1,1,0,0]
DY=[0,0,-1,1]
class Env(object):
    def __init__ (self):
        self.map=copy.deepcopy(MAP)
        self.x=1
        self.y=1
        self.step=0
        self.total_reward=0
        self.is_end=False
    def interact(self,action):
        assert self.is_end is False
        new_x=self.x+DX[action]
        new_y=self.y+DY[action]
        new_pos_char=self.map[new_x][new_y]
        self.step+=1
        if new_pos_char=='.':
            reward=0
            # donot change position
        elif new_pos_char == ' ':
            self.x = new_x
            self.y = new_y
            reward = 0
        elif new_pos_char=='o':
            self.x=new_x
            self.y=new_y
            self.map[new_x][new_y]=' '
            self.is_end=True #end
            reward=100
        elif new_pos_char=='x':
            self.x=new_x
            self.y=new_y
            self.map[new_x][new_y]=' '
            reward = -5
        self.total_reward+=reward
        return reward
    
    @property
    def state_num(self):
        #Python内置的@property装饰器就是负责把一个方法变成属性调用的
        rows=len(self.map)
        cols=len(self.map[0])
        return rows*cols
    
    @property
    def present_state(self):
        cols=len(self.map[0])
        return self.x*cols+self.y
    
    def print_map(self):
        printed_map=copy.deepcopy(self.map)
        printed_map[self.x][self.y]='A'
        print('\n'.join([''.join([c for c in line])for line in printed_map]))
    def print_map_with_reprint(self, output_list):
        printed_map = copy.deepcopy(self.map)
        printed_map[self.x][self.y] = 'A'
        printed_list = [''.join([c for c in line]) for line in printed_map]
        for i, line in enumerate(printed_list):
            output_list[i] = line

# %%
def epsilon_greedy(Q, state):
    if (np.random.uniform() > 1 - EPSILON) or ((Q[state, :] == 0).all()):
        action = np.random.randint(0, 4)  # 0~3
    else:
        action = Q[state, :].argmax()
    return action

# %%
import numpy as np
import time
EPSILON = 0.1
ALPHA = 0.1
GAMMA = 0.9
MAX_STEP = 30
e=Env()
Q=np.zeros((e.state_num,4))
for i in range(200):
    e=Env()
    while(e.is_end is False)and(e.step<MAX_STEP):
        action=epsilon_greedy(Q,e.present_state)
        state=e.present_state
        reward=e.interact(action)
        new_state=e.present_state
        Q[state,action]=(1-ALPHA)*Q[state,action]+ALPHA*(reward+GAMMA*Q[new_state,:].max())
        e.print_map()
        time.sleep(0.1)
    print('Episode:',i,'Total Step:',e.step,'Total Reward:',e.total_reward)
    time.sleep(2)
# Out:
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# .       .
# .     o .
# . A     .
# .........
# .........
# .       .
# .     o .
# . A     .
# .........
# .........
# .       .
# .     o .
# .  A    .
# .........
# .........
# .       .
# .     o .
# . A     .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# .       .
# .     o .
# . A     .
# .........
# .........
# .       .
# .     o .
# . A     .
# .........
# .........
# .       .
# .     o .
# . A     .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# .       .
# .  A  o .
# .       .
# .........
# Episode: 0 Total Step: 30 Total Reward: 0
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .       .
# .  A  o .
# .       .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .       .
# .  A  o .
# .       .
# .........
# .........
# .       .
# .     o .
# .  A    .
# .........
# .........
# .       .
# .  A  o .
# .       .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# .       .
# .     o .
# . A     .
# .........
# .........
# .       .
# .     o .
# . A     .
# .........
# .........
# .       .
# .     o .
# .  A    .
# .........
# .........
# .       .
# .     o .
# .  A    .
# .........
# .........
# .       .
# .     o .
# .  A    .
# .........
# .........
# .       .
# .     o .
# .   A   .
# .........
# .........
# .       .
# .     o .
# .  A    .
# .........
# .........
# .       .
# .     o .
# .   A   .
# .........
# Episode: 1 Total Step: 30 Total Reward: 0
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# .       .
# .     o .
# . A     .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .     o .
# . A     .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# .       .
# .     o .
# . A     .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# .       .
# .  A  o .
# .       .
# .........
# .........
# .       .
# .   A o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .       .
# .   A o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .    A  .
# .     o .
# .       .
# .........
# .........
# .       .
# .    Ao .
# .       .
# .........
# Episode: 2 Total Step: 30 Total Reward: 0
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .       .
# .  A  o .
# .       .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# .       .
# .  A  o .
# .       .
# .........
# .........
# .       .
# .     o .
# .  A    .
# .........
# .........
# .       .
# .     o .
# .  A    .
# .........
# .........
# .       .
# .     o .
# . A     .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .     o .
# . A     .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# Episode: 3 Total Step: 30 Total Reward: 0
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# .       .
# .  A  o .
# .       .
# .........
# .........
# .       .
# .   A o .
# .       .
# .........
# .........
# .       .
# .     o .
# .   A   .
# .........
# .........
# .       .
# .     o .
# .    A  .
# .........
# .........
# .       .
# .    Ao .
# .       .
# .........
# .........
# .       .
# .     o .
# .    A  .
# .........
# .........
# .       .
# .    Ao .
# .       .
# .........
# .........
# .       .
# .   A o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .    A  .
# .     o .
# .       .
# .........
# .........
# .       .
# .    Ao .
# .       .
# .........
# .........
# .       .
# .   A o .
# .       .
# .........
# .........
# .       .
# .  A  o .
# .       .
# .........
# .........
# .       .
# .   A o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# Episode: 4 Total Step: 30 Total Reward: 0
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# .       .
# .     o .
# . A     .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .       .
# .  A  o .
# .       .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# Episode: 5 Total Step: 30 Total Reward: 0
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .    A  .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .       .
# .  A  o .
# .       .
# .........
# .........
# .       .
# .     o .
# .  A    .
# .........
# .........
# .       .
# .  A  o .
# .       .
# .........
# .........
# .       .
# .   A o .
# .       .
# .........
# .........
# .       .
# .     o .
# .   A   .
# .........
# .........
# .       .
# .   A o .
# .       .
# .........
# .........
# .       .
# .     o .
# .   A   .
# .........
# .........
# .       .
# .     o .
# .  A    .
# .........
# .........
# .       .
# .     o .
# . A     .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# Episode: 6 Total Step: 30 Total Reward: 0
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .     o .
# . A     .
# .........
# .........
# .       .
# .     o .
# . A     .
# .........
# .........
# .       .
# .     o .
# . A     .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .     o .
# . A     .
# .........
# .........
# .       .
# .     o .
# .  A    .
# .........
# .........
# .       .
# .     o .
# .  A    .
# .........
# .........
# .       .
# .     o .
# .   A   .
# .........
# .........
# .       .
# .     o .
# .  A    .
# .........
# .........
# .       .
# .     o .
# .   A   .
# .........
# .........
# .       .
# .   A o .
# .       .
# .........
# .........
# .       .
# .     o .
# .   A   .
# .........
# .........
# .       .
# .     o .
# .  A    .
# .........
# .........
# .       .
# .     o .
# .   A   .
# .........
# .........
# .       .
# .   A o .
# .       .
# .........
# .........
# .       .
# .  A  o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .    A  .
# .     o .
# .       .
# .........
# .........
# .     A .
# .     o .
# .       .
# .........
# .........
# .     A .
# .     o .
# .       .
# .........
# .........
# .    A  .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# Episode: 7 Total Step: 30 Total Reward: 0
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# .       .
# .     o .
# . A     .
# .........
# .........
# .       .
# .     o .
# . A     .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .     o .
# . A     .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .     o .
# . A     .
# .........
# Episode: 8 Total Step: 30 Total Reward: 0
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# .       .
# .  A  o .
# .       .
# .........
# .........
# .       .
# .     o .
# .  A    .
# .........
# .........
# .       .
# .  A  o .
# .       .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# .       .
# .     o .
# . A     .
# .........
# .........
# .       .
# .     o .
# .  A    .
# .........
# .........
# .       .
# .     o .
# .  A    .
# .........
# .........
# .       .
# .     o .
# .  A    .
# .........
# .........
# .       .
# .     o .
# .   A   .
# .........
# .........
# .       .
# .   A o .
# .       .
# .........
# .........
# .       .
# .    Ao .
# .       .
# .........
# Episode: 9 Total Step: 30 Total Reward: 0
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# .       .
# .  A  o .
# .       .
# .........
# .........
# .       .
# .   A o .
# .       .
# .........
# .........
# .       .
# .    Ao .
# .       .
# .........
# .........
# .    A  .
# .     o .
# .       .
# .........
# .........
# .    A  .
# .     o .
# .       .
# .........
# .........
# .       .
# .    Ao .
# .       .
# .........
# .........
# .    A  .
# .     o .
# .       .
# .........
# .........
# .     A .
# .     o .
# .       .
# .........
# .........
# .     A .
# .     o .
# .       .
# .........
# .........
# .     A .
# .     o .
# .       .
# .........
# .........
# .      A.
# .     o .
# .       .
# .........
# .........
# .      A.
# .     o .
# .       .
# .........
# .........
# .       .
# .     oA.
# .       .
# .........
# .........
# .       .
# .     A .
# .       .
# .........
# Episode: 10 Total Step: 20 Total Reward: 100
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .       .
# .  A  o .
# .       .
# .........
# .........
# .       .
# .     o .
# .  A    .
# .........
# .........
# .       .
# .     o .
# . A     .
# .........
# .........
# .       .
# .     o .
# . A     .
# .........
# .........
# .       .
# .     o .
# .  A    .
# .........
# .........
# .       .
# .     o .
# . A     .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# .       .
# .     o .
# . A     .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# .       .
# .  A  o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# .       .
# .  A  o .
# .       .
# .........
# .........
# .       .
# .     o .
# .  A    .
# .........
# .........
# .       .
# .     o .
# .   A   .
# .........
# .........
# .       .
# .     o .
# .  A    .
# .........
# .........
# .       .
# .     o .
# .   A   .
# .........
# .........
# .       .
# .     o .
# .    A  .
# .........
# .........
# .       .
# .     o .
# .    A  .
# .........
# .........
# .       .
# .     o .
# .    A  .
# .........
# .........
# .       .
# .    Ao .
# .       .
# .........
# .........
# .    A  .
# .     o .
# .       .
# .........
# .........
# .       .
# .    Ao .
# .       .
# .........
# Episode: 11 Total Step: 30 Total Reward: 0
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .       .
# .   A o .
# .       .
# .........
# .........
# .       .
# .    Ao .
# .       .
# .........
# .........
# .       .
# .   A o .
# .       .
# .........
# .........
# .       .
# .  A  o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .       .
# .   A o .
# .       .
# .........
# .........
# .       .
# .    Ao .
# .       .
# .........
# .........
# .       .
# .   A o .
# .       .
# .........
# .........
# .       .
# .    Ao .
# .       .
# .........
# .........
# .       .
# .     o .
# .    A  .
# .........
# .........
# .       .
# .     o .
# .   A   .
# .........
# .........
# .       .
# .     o .
# .   A   .
# .........
# .........
# .       .
# .     o .
# .    A  .
# .........
# .........
# .       .
# .    Ao .
# .       .
# .........
# .........
# .       .
# .     A .
# .       .
# .........
# Episode: 12 Total Step: 28 Total Reward: 100
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# .       .
# .     o .
# . A     .
# .........
# .........
# .       .
# .     o .
# . A     .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .     o .
# . A     .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .     o .
# . A     .
# .........
# .........
# .       .
# .     o .
# .  A    .
# .........
# .........
# .       .
# .     o .
# . A     .
# .........
# .........
# .       .
# .     o .
# .  A    .
# .........
# .........
# .       .
# .  A  o .
# .       .
# .........
# .........
# .       .
# .     o .
# .  A    .
# .........
# .........
# .       .
# .     o .
# . A     .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# .       .
# .  A  o .
# .       .
# .........
# .........
# .       .
# .   A o .
# .       .
# .........
# .........
# .       .
# .     o .
# .   A   .
# .........
# .........
# .       .
# .     o .
# .  A    .
# .........
# .........
# .       .
# .  A  o .
# .       .
# .........
# .........
# .       .
# .   A o .
# .       .
# .........
# .........
# .       .
# .     o .
# .   A   .
# .........
# .........
# .       .
# .   A o .
# .       .
# .........
# Episode: 13 Total Step: 30 Total Reward: 0
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .       .
# .  A  o .
# .       .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# .       .
# .     o .
# . A     .
# .........
# .........
# .       .
# .     o .
# . A     .
# .........
# .........
# .       .
# .     o .
# . A     .
# .........
# .........
# .       .
# .     o .
# .  A    .
# .........
# .........
# .       .
# .     o .
# .   A   .
# .........
# .........
# .       .
# .     o .
# .    A  .
# .........
# .........
# .       .
# .     o .
# .     A .
# .........
# .........
# .       .
# .     A .
# .       .
# .........
# Episode: 14 Total Step: 17 Total Reward: 100
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .    A  .
# .     o .
# .       .
# .........
# .........
# .    A  .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .       .
# .  A  o .
# .       .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# .       .
# .  A  o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# Episode: 15 Total Step: 30 Total Reward: 0
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .     o .
# . A     .
# .........
# .........
# .       .
# .     o .
# .  A    .
# .........
# .........
# .       .
# .  A  o .
# .       .
# .........
# .........
# .       .
# .   A o .
# .       .
# .........
# .........
# .       .
# .    Ao .
# .       .
# .........
# .........
# .       .
# .     A .
# .       .
# .........
# Episode: 16 Total Step: 18 Total Reward: 100
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .     o .
# . A     .
# .........
# .........
# .       .
# .     o .
# .  A    .
# .........
# .........
# .       .
# .     o .
# . A     .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .    A  .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .       .
# .   A o .
# .       .
# .........
# .........
# .       .
# .    Ao .
# .       .
# .........
# .........
# .       .
# .     A .
# .       .
# .........
# Episode: 17 Total Step: 19 Total Reward: 100
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# Episode: 18 Total Step: 30 Total Reward: 0
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .       .
# .  A  o .
# .       .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# .       .
# .  A  o .
# .       .
# .........
# .........
# .       .
# .     o .
# .  A    .
# .........
# .........
# .       .
# .     o .
# .   A   .
# .........
# .........
# .       .
# .     o .
# .   A   .
# .........
# .........
# .       .
# .     o .
# .   A   .
# .........
# .........
# .       .
# .   A o .
# .       .
# .........
# .........
# .       .
# .     o .
# .   A   .
# .........
# .........
# .       .
# .   A o .
# .       .
# .........
# .........
# .       .
# .    Ao .
# .       .
# .........
# .........
# .       .
# .     A .
# .       .
# .........
# Episode: 19 Total Step: 16 Total Reward: 100
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# .       .
# .  A  o .
# .       .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .       .
# .   A o .
# .       .
# .........
# .........
# .       .
# .    Ao .
# .       .
# .........
# .........
# .       .
# .     A .
# .       .
# .........
# Episode: 20 Total Step: 11 Total Reward: 100
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .       .
# .   A o .
# .       .
# .........
# .........
# .       .
# .    Ao .
# .       .
# .........
# .........
# .       .
# .     A .
# .       .
# .........
# Episode: 21 Total Step: 7 Total Reward: 100
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# .       .
# .  A  o .
# .       .
# .........
# .........
# .       .
# .   A o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .       .
# .   A o .
# .       .
# .........
# .........
# .       .
# .  A  o .
# .       .
# .........
# .........
# .       .
# .   A o .
# .       .
# .........
# .........
# .       .
# .    Ao .
# .       .
# .........
# .........
# .       .
# .     o .
# .    A  .
# .........
# .........
# .       .
# .     o .
# .     A .
# .........
# .........
# .       .
# .     A .
# .       .
# .........
# Episode: 22 Total Step: 21 Total Reward: 100
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .       .
# .   A o .
# .       .
# .........
# .........
# .       .
# .  A  o .
# .       .
# .........
# .........
# .       .
# .   A o .
# .       .
# .........
# .........
# .       .
# .    Ao .
# .       .
# .........
# .........
# .       .
# .     A .
# .       .
# .........
# Episode: 23 Total Step: 8 Total Reward: 100
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .       .
# .   A o .
# .       .
# .........
# .........
# .       .
# .    Ao .
# .       .
# .........
# .........
# .       .
# .     A .
# .       .
# .........
# Episode: 24 Total Step: 6 Total Reward: 100
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .       .
# .   A o .
# .       .
# .........
# .........
# .       .
# .    Ao .
# .       .
# .........
# .........
# .       .
# .     A .
# .       .
# .........
# Episode: 25 Total Step: 7 Total Reward: 100
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .       .
# .   A o .
# .       .
# .........
# .........
# .       .
# .    Ao .
# .       .
# .........
# .........
# .       .
# .     A .
# .       .
# .........
# Episode: 26 Total Step: 7 Total Reward: 100
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .       .
# .   A o .
# .       .
# .........
# .........
# .       .
# .    Ao .
# .       .
# .........
# .........
# .       .
# .     A .
# .       .
# .........
# Episode: 27 Total Step: 6 Total Reward: 100
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .       .
# .   A o .
# .       .
# .........
# .........
# .       .
# .    Ao .
# .       .
# .........
# .........
# .       .
# .     A .
# .       .
# .........
# Episode: 28 Total Step: 6 Total Reward: 100
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .       .
# .   A o .
# .       .
# .........
# .........
# .       .
# .    Ao .
# .       .
# .........
# .........
# .       .
# .     A .
# .       .
# .........
# Episode: 29 Total Step: 6 Total Reward: 100
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .       .
# .   A o .
# .       .
# .........
# .........
# .       .
# .    Ao .
# .       .
# .........
# .........
# .       .
# .     A .
# .       .
# .........
# Episode: 30 Total Step: 7 Total Reward: 100
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# .       .
# .     o .
# . A     .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .     o .
# . A     .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .       .
# .   A o .
# .       .
# .........
# .........
# .       .
# .    Ao .
# .       .
# .........
# .........
# .       .
# .     o .
# .    A  .
# .........
# .........
# .       .
# .     o .
# .     A .
# .........
# .........
# .       .
# .     A .
# .       .
# .........
# Episode: 31 Total Step: 23 Total Reward: 100
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .       .
# .   A o .
# .       .
# .........
# .........
# .       .
# .    Ao .
# .       .
# .........
# .........
# .       .
# .     A .
# .       .
# .........
# Episode: 32 Total Step: 6 Total Reward: 100
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .       .
# .   A o .
# .       .
# .........
# .........
# .       .
# .    Ao .
# .       .
# .........
# .........
# .       .
# .     A .
# .       .
# .........
# Episode: 33 Total Step: 6 Total Reward: 100
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .       .
# .   A o .
# .       .
# .........
# .........
# .       .
# .    Ao .
# .       .
# .........
# .........
# .       .
# .     A .
# .       .
# .........
# Episode: 34 Total Step: 6 Total Reward: 100
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .       .
# .   A o .
# .       .
# .........
# .........
# .       .
# .    Ao .
# .       .
# .........
# .........
# .       .
# .     A .
# .       .
# .........
# Episode: 35 Total Step: 6 Total Reward: 100
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .       .
# .   A o .
# .       .
# .........
# .........
# .       .
# .    Ao .
# .       .
# .........
# .........
# .       .
# .     A .
# .       .
# .........
# Episode: 36 Total Step: 7 Total Reward: 100
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .       .
# .   A o .
# .       .
# .........
# .........
# .       .
# .    Ao .
# .       .
# .........
# .........
# .       .
# .     o .
# .    A  .
# .........
# .........
# .       .
# .     o .
# .     A .
# .........
# .........
# .       .
# .     A .
# .       .
# .........
# Episode: 37 Total Step: 8 Total Reward: 100
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .       .
# .   A o .
# .       .
# .........
# .........
# .       .
# .    Ao .
# .       .
# .........
# .........
# .       .
# .     A .
# .       .
# .........
# Episode: 38 Total Step: 6 Total Reward: 100
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .       .
# .   A o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .       .
# .   A o .
# .       .
# .........
# .........
# .       .
# .    Ao .
# .       .
# .........
# .........
# .       .
# .     A .
# .       .
# .........
# Episode: 39 Total Step: 8 Total Reward: 100
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .       .
# .   A o .
# .       .
# .........
# .........
# .       .
# .    Ao .
# .       .
# .........
# .........
# .       .
# .     A .
# .       .
# .........
# Episode: 40 Total Step: 6 Total Reward: 100
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .       .
# .   A o .
# .       .
# .........
# .........
# .       .
# .    Ao .
# .       .
# .........
# .........
# .       .
# .     A .
# .       .
# .........
# Episode: 41 Total Step: 6 Total Reward: 100
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .       .
# .   A o .
# .       .
# .........
# .........
# .       .
# .    Ao .
# .       .
# .........
# .........
# .       .
# .     A .
# .       .
# .........
# Episode: 42 Total Step: 6 Total Reward: 100
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .       .
# .   A o .
# .       .
# .........
# .........
# .       .
# .    Ao .
# .       .
# .........
# .........
# .       .
# .     A .
# .       .
# .........
# Episode: 43 Total Step: 6 Total Reward: 100
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .       .
# .   A o .
# .       .
# .........
# .........
# .       .
# .    Ao .
# .       .
# .........
# .........
# .       .
# .     A .
# .       .
# .........
# Episode: 44 Total Step: 6 Total Reward: 100
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .       .
# .   A o .
# .       .
# .........
# .........
# .       .
# .    Ao .
# .       .
# .........
# .........
# .       .
# .     A .
# .       .
# .........
# Episode: 45 Total Step: 7 Total Reward: 100
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .       .
# .   A o .
# .       .
# .........
# .........
# .       .
# .    Ao .
# .       .
# .........
# .........
# .       .
# .     A .
# .       .
# .........
# Episode: 46 Total Step: 6 Total Reward: 100
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .       .
# .   A o .
# .       .
# .........
# .........
# .       .
# .    Ao .
# .       .
# .........
# .........
# .       .
# .     A .
# .       .
# .........
# Episode: 47 Total Step: 6 Total Reward: 100
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .       .
# .   A o .
# .       .
# .........
# .........
# .       .
# .    Ao .
# .       .
# .........
# .........
# .       .
# .     A .
# .       .
# .........
# Episode: 48 Total Step: 6 Total Reward: 100
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .       .
# .   A o .
# .       .
# .........
# .........
# .       .
# .    Ao .
# .       .
# .........
# .........
# .       .
# .     A .
# .       .
# .........
# Episode: 49 Total Step: 6 Total Reward: 100
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .       .
# .   A o .
# .       .
# .........
# .........
# .       .
# .    Ao .
# .       .
# .........
# .........
# .       .
# .     A .
# .       .
# .........
# Episode: 50 Total Step: 6 Total Reward: 100
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .       .
# .   A o .
# .       .
# .........
# .........
# .       .
# .    Ao .
# .       .
# .........
# .........
# .       .
# .     A .
# .       .
# .........
# Episode: 51 Total Step: 6 Total Reward: 100
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .       .
# .   A o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .       .
# .   A o .
# .       .
# .........
# .........
# .       .
# .    Ao .
# .       .
# .........
# .........
# .       .
# .     A .
# .       .
# .........
# Episode: 52 Total Step: 8 Total Reward: 100
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .       .
# .   A o .
# .       .
# .........
# .........
# .       .
# .    Ao .
# .       .
# .........
# .........
# .       .
# .     A .
# .       .
# .........
# Episode: 53 Total Step: 6 Total Reward: 100
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .       .
# .   A o .
# .       .
# .........
# .........
# .       .
# .    Ao .
# .       .
# .........
# .........
# .       .
# .     A .
# .       .
# .........
# Episode: 54 Total Step: 6 Total Reward: 100
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .       .
# .   A o .
# .       .
# .........
# .........
# .       .
# .    Ao .
# .       .
# .........
# .........
# .       .
# .     A .
# .       .
# .........
# Episode: 55 Total Step: 6 Total Reward: 100
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .       .
# .   A o .
# .       .
# .........
# .........
# .       .
# .    Ao .
# .       .
# .........
# .........
# .       .
# .     A .
# .       .
# .........
# Episode: 56 Total Step: 6 Total Reward: 100
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .       .
# .   A o .
# .       .
# .........
# .........
# .       .
# .    Ao .
# .       .
# .........
# .........
# .       .
# .     A .
# .       .
# .........
# Episode: 57 Total Step: 6 Total Reward: 100
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .       .
# .   A o .
# .       .
# .........
# .........
# .       .
# .    Ao .
# .       .
# .........
# .........
# .       .
# .     A .
# .       .
# .........
# Episode: 58 Total Step: 6 Total Reward: 100
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .       .
# .   A o .
# .       .
# .........
# .........
# .       .
# .    Ao .
# .       .
# .........
# .........
# .       .
# .     A .
# .       .
# .........
# Episode: 59 Total Step: 6 Total Reward: 100
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .       .
# .   A o .
# .       .
# .........
# .........
# .       .
# .    Ao .
# .       .
# .........
# .........
# .       .
# .     A .
# .       .
# .........
# Episode: 60 Total Step: 6 Total Reward: 100
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .       .
# .   A o .
# .       .
# .........
# .........
# .       .
# .    Ao .
# .       .
# .........
# .........
# .       .
# .     A .
# .       .
# .........
# Episode: 61 Total Step: 6 Total Reward: 100
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .       .
# .   A o .
# .       .
# .........
# .........
# .       .
# .    Ao .
# .       .
# .........
# .........
# .       .
# .     A .
# .       .
# .........
# Episode: 62 Total Step: 6 Total Reward: 100
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .       .
# .   A o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .       .
# .   A o .
# .       .
# .........
# .........
# .       .
# .    Ao .
# .       .
# .........
# .........
# .       .
# .     A .
# .       .
# .........
# Episode: 63 Total Step: 8 Total Reward: 100
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .       .
# .   A o .
# .       .
# .........
# .........
# .       .
# .    Ao .
# .       .
# .........
# .........
# .       .
# .     A .
# .       .
# .........
# Episode: 64 Total Step: 13 Total Reward: 100
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .       .
# .   A o .
# .       .
# .........
# .........
# .       .
# .    Ao .
# .       .
# .........
# .........
# .       .
# .     A .
# .       .
# .........
# Episode: 65 Total Step: 6 Total Reward: 100
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .       .
# .   A o .
# .       .
# .........
# .........
# .       .
# .    Ao .
# .       .
# .........
# .........
# .       .
# .     A .
# .       .
# .........
# Episode: 66 Total Step: 7 Total Reward: 100
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .       .
# .   A o .
# .       .
# .........
# .........
# .       .
# .    Ao .
# .       .
# .........
# .........
# .       .
# .     A .
# .       .
# .........
# Episode: 67 Total Step: 6 Total Reward: 100
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .       .
# .   A o .
# .       .
# .........
# .........
# .       .
# .    Ao .
# .       .
# .........
# .........
# .       .
# .     A .
# .       .
# .........
# Episode: 68 Total Step: 9 Total Reward: 100
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .       .
# .   A o .
# .       .
# .........
# .........
# .       .
# .    Ao .
# .       .
# .........
# .........
# .       .
# .     A .
# .       .
# .........
# Episode: 69 Total Step: 6 Total Reward: 100
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-36fd2630eaeb> in <module>()
#      18         time.sleep(0.1)
#      19     print('Episode:',i,'Total Step:',e.step,'Total Reward:',e.total_reward)
# ---> 20     time.sleep(2)
#
# KeyboardInterrupt:

# %%
from __future__ import print_function
import numpy as np
import time
from reprint import output


EPSILON = 0.1
ALPHA = 0.1
GAMMA = 0.9
MAX_STEP = 30

np.random.seed(0)


def epsilon_greedy(Q, state):
    if (np.random.uniform() > 1 - EPSILON) or ((Q[state, :] == 0).all()):
        action = np.random.randint(0, 4)  # 0~3
    else:
        action = Q[state, :].argmax()
    return action


e = Env()
Q = np.zeros((e.state_num, 4))

with output(output_type="list", initial_len=len(e.map), interval=0) as output_list:
    for i in range(100):
        e = Env()
        while (e.is_end is False) and (e.step < MAX_STEP):
            action = epsilon_greedy(Q, e.present_state)
            state = e.present_state
            reward = e.interact(action)
            new_state = e.present_state
            Q[state, action] = (1 - ALPHA) * Q[state, action] + \
                ALPHA * (reward + GAMMA * Q[new_state, :].max())
            e.print_map_with_reprint(output_list)
            time.sleep(0.1)
        for line_num in range(len(e.map)):
            if line_num == 0:
                output_list[0] = 'Episode:{} Total Step:{}, Total Reward:{}'.format(i, e.step, e.total_reward)
            else:
                output_list[line_num] = ''
        time.sleep(2)
# Out:
# Not in terminal, reprint now using normal build-in print function.
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# .       .
# .     o .
# . A     .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# .       .
# .     o .
# . A     .
# .........
# .........
# .       .
# .     o .
# .  A    .
# .........
# .........
# .       .
# .     o .
# .   A   .
# .........
# .........
# .       .
# .     o .
# .    A  .
# .........
# .........
# .       .
# .     o .
# .     A .
# .........
# .........
# .       .
# .     A .
# .       .
# .........
# Episode:0 Total Step:17, Total Reward:100
#
#
#
#
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# .       .
# .  A  o .
# .       .
# .........
# .........
# .       .
# .   A o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .       .
# .   A o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .       .
# .  A  o .
# .       .
# .........
# .........
# .       .
# .     o .
# .  A    .
# .........
# .........
# .       .
# .     o .
# . A     .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# .       .
# .  A  o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .       .
# .  A  o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .       .
# .  A  o .
# .       .
# .........
# .........
# .       .
# .   A o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .       .
# .   A o .
# .       .
# .........
# Episode:1 Total Step:30, Total Reward:0
#
#
#
#
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .     o .
# . A     .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# Episode:2 Total Step:30, Total Reward:0
#
#
#
#
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .       .
# .  A  o .
# .       .
# .........
# .........
# .       .
# .   A o .
# .       .
# .........
# .........
# .       .
# .    Ao .
# .       .
# .........
# .........
# .    A  .
# .     o .
# .       .
# .........
# .........
# .     A .
# .     o .
# .       .
# .........
# .........
# .       .
# .     A .
# .       .
# .........
# Episode:3 Total Step:13, Total Reward:100
#
#
#
#
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .       .
# .  A  o .
# .       .
# .........
# .........
# .       .
# .   A o .
# .       .
# .........
# .........
# .       .
# .    Ao .
# .       .
# .........
# .........
# .       .
# .     A .
# .       .
# .........
# Episode:4 Total Step:13, Total Reward:100
#
#
#
#
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# .       .
# .     o .
# . A     .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .     o .
# . A     .
# .........
# .........
# .       .
# .     o .
# .  A    .
# .........
# .........
# .       .
# .     o .
# . A     .
# .........
# Episode:5 Total Step:30, Total Reward:0
#
#
#
#
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .       .
# .  A  o .
# .       .
# .........
# .........
# .       .
# .     o .
# .  A    .
# .........
# .........
# .       .
# .     o .
# . A     .
# .........
# .........
# .       .
# .     o .
# . A     .
# .........
# .........
# .       .
# .     o .
# . A     .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# .       .
# .  A  o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .       .
# .  A  o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# .       .
# .  A  o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# Episode:6 Total Step:30, Total Reward:0
#
#
#
#
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .     o .
# . A     .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .    A  .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .    A  .
# .     o .
# .       .
# .........
# .........
# .    A  .
# .     o .
# .       .
# .........
# .........
# .     A .
# .     o .
# .       .
# .........
# .........
# .       .
# .     A .
# .       .
# .........
# Episode:7 Total Step:24, Total Reward:100
#
#
#
#
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# .       .
# .     o .
# . A     .
# .........
# .........
# .       .
# .     o .
# .  A    .
# .........
# .........
# .       .
# .     o .
# . A     .
# .........
# .........
# .       .
# .     o .
# . A     .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .       .
# .  A  o .
# .       .
# .........
# .........
# .       .
# .     o .
# .  A    .
# .........
# .........
# .       .
# .  A  o .
# .       .
# .........
# .........
# .       .
# .     o .
# .  A    .
# .........
# .........
# .       .
# .     o .
# .   A   .
# .........
# .........
# .       .
# .   A o .
# .       .
# .........
# .........
# .       .
# .  A  o .
# .       .
# .........
# .........
# .       .
# .     o .
# .  A    .
# .........
# .........
# .       .
# .     o .
# .  A    .
# .........
# .........
# .       .
# .     o .
# . A     .
# .........
# .........
# .       .
# .     o .
# . A     .
# .........
# .........
# .       .
# .     o .
# . A     .
# .........
# Episode:8 Total Step:30, Total Reward:0
#
#
#
#
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .       .
# .   A o .
# .       .
# .........
# .........
# .       .
# .  A  o .
# .       .
# .........
# .........
# .       .
# .   A o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .    A  .
# .     o .
# .       .
# .........
# .........
# .     A .
# .     o .
# .       .
# .........
# .........
# .       .
# .     A .
# .       .
# .........
# Episode:9 Total Step:17, Total Reward:100
#
#
#
#
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# .       .
# .     o .
# . A     .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .     o .
# . A     .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# Episode:10 Total Step:30, Total Reward:0
#
#
#
#
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .       .
# .  A  o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# .       .
# .     o .
# . A     .
# .........
# .........
# .       .
# .     o .
# .  A    .
# .........
# .........
# .       .
# .     o .
# .  A    .
# .........
# .........
# .       .
# .  A  o .
# .       .
# .........
# .........
# .       .
# .     o .
# .  A    .
# .........
# .........
# .       .
# .     o .
# . A     .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .     o .
# . A     .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .     o .
# . A     .
# .........
# .........
# .       .
# .     o .
# .  A    .
# .........
# .........
# .       .
# .     o .
# .   A   .
# .........
# .........
# .       .
# .     o .
# .   A   .
# .........
# .........
# .       .
# .     o .
# .    A  .
# .........
# .........
# .       .
# .     o .
# .   A   .
# .........
# Episode:11 Total Step:30, Total Reward:0
#
#
#
#
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .    A  .
# .     o .
# .       .
# .........
# .........
# .     A .
# .     o .
# .       .
# .........
# .........
# .       .
# .     A .
# .       .
# .........
# Episode:12 Total Step:10, Total Reward:100
#
#
#
#
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# .       .
# .  A  o .
# .       .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .     o .
# . A     .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# Episode:13 Total Step:30, Total Reward:0
#
#
#
#
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .    A  .
# .     o .
# .       .
# .........
# .........
# .     A .
# .     o .
# .       .
# .........
# .........
# .       .
# .     A .
# .       .
# .........
# Episode:14 Total Step:8, Total Reward:100
#
#
#
#
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .     o .
# . A     .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .     o .
# . A     .
# .........
# .........
# .       .
# .     o .
# . A     .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# .       .
# .     o .
# . A     .
# .........
# .........
# .       .
# .     o .
# .  A    .
# .........
# .........
# .       .
# .  A  o .
# .       .
# .........
# .........
# .       .
# .     o .
# .  A    .
# .........
# .........
# .       .
# .     o .
# .  A    .
# .........
# .........
# .       .
# .  A  o .
# .       .
# .........
# .........
# .       .
# .     o .
# .  A    .
# .........
# .........
# .       .
# .  A  o .
# .       .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# .       .
# .  A  o .
# .       .
# .........
# .........
# .       .
# .   A o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .    A  .
# .     o .
# .       .
# .........
# .........
# .     A .
# .     o .
# .       .
# .........
# .........
# .       .
# .     A .
# .       .
# .........
# Episode:15 Total Step:30, Total Reward:100
#
#
#
#
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .    A  .
# .     o .
# .       .
# .........
# .........
# .     A .
# .     o .
# .       .
# .........
# .........
# .       .
# .     A .
# .       .
# .........
# Episode:16 Total Step:7, Total Reward:100
#
#
#
#
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .       .
# .  A  o .
# .       .
# .........
# .........
# .       .
# .   A o .
# .       .
# .........
# .........
# .       .
# .    Ao .
# .       .
# .........
# .........
# .       .
# .     A .
# .       .
# .........
# Episode:17 Total Step:6, Total Reward:100
#
#
#
#
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .    A  .
# .     o .
# .       .
# .........
# .........
# .     A .
# .     o .
# .       .
# .........
# .........
# .       .
# .     A .
# .       .
# .........
# Episode:18 Total Step:6, Total Reward:100
#
#
#
#
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .    A  .
# .     o .
# .       .
# .........
# .........
# .     A .
# .     o .
# .       .
# .........
# .........
# .       .
# .     A .
# .       .
# .........
# Episode:19 Total Step:10, Total Reward:100
#
#
#
#
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .    A  .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .    A  .
# .     o .
# .       .
# .........
# .........
# .     A .
# .     o .
# .       .
# .........
# .........
# .       .
# .     A .
# .       .
# .........
# Episode:20 Total Step:8, Total Reward:100
#
#
#
#
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .    A  .
# .     o .
# .       .
# .........
# .........
# .     A .
# .     o .
# .       .
# .........
# .........
# .       .
# .     A .
# .       .
# .........
# Episode:21 Total Step:6, Total Reward:100
#
#
#
#
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .    A  .
# .     o .
# .       .
# .........
# .........
# .     A .
# .     o .
# .       .
# .........
# .........
# .       .
# .     A .
# .       .
# .........
# Episode:22 Total Step:7, Total Reward:100
#
#
#
#
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .    A  .
# .     o .
# .       .
# .........
# .........
# .     A .
# .     o .
# .       .
# .........
# .........
# .     A .
# .     o .
# .       .
# .........
# .........
# .       .
# .     A .
# .       .
# .........
# Episode:23 Total Step:7, Total Reward:100
#
#
#
#
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .    A  .
# .     o .
# .       .
# .........
# .........
# .     A .
# .     o .
# .       .
# .........
# .........
# .     A .
# .     o .
# .       .
# .........
# .........
# .       .
# .     A .
# .       .
# .........
# Episode:24 Total Step:7, Total Reward:100
#
#
#
#
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .    A  .
# .     o .
# .       .
# .........
# .........
# .     A .
# .     o .
# .       .
# .........
# .........
# .       .
# .     A .
# .       .
# .........
# Episode:25 Total Step:6, Total Reward:100
#
#
#
#
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .    A  .
# .     o .
# .       .
# .........
# .........
# .     A .
# .     o .
# .       .
# .........
# .........
# .       .
# .     A .
# .       .
# .........
# Episode:26 Total Step:6, Total Reward:100
#
#
#
#
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .    A  .
# .     o .
# .       .
# .........
# .........
# .     A .
# .     o .
# .       .
# .........
# .........
# .       .
# .     A .
# .       .
# .........
# Episode:27 Total Step:10, Total Reward:100
#
#
#
#
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .    A  .
# .     o .
# .       .
# .........
# .........
# .     A .
# .     o .
# .       .
# .........
# .........
# .       .
# .     A .
# .       .
# .........
# Episode:28 Total Step:6, Total Reward:100
#
#
#
#
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .    A  .
# .     o .
# .       .
# .........
# .........
# .     A .
# .     o .
# .       .
# .........
# .........
# .       .
# .     A .
# .       .
# .........
# Episode:29 Total Step:8, Total Reward:100
#
#
#
#
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .    A  .
# .     o .
# .       .
# .........
# .........
# .     A .
# .     o .
# .       .
# .........
# .........
# .       .
# .     A .
# .       .
# .........
# Episode:30 Total Step:6, Total Reward:100
#
#
#
#
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .    A  .
# .     o .
# .       .
# .........
# .........
# .     A .
# .     o .
# .       .
# .........
# .........
# .       .
# .     A .
# .       .
# .........
# Episode:31 Total Step:6, Total Reward:100
#
#
#
#
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# .       .
# .     o .
# . A     .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# .       .
# .  A  o .
# .       .
# .........
# .........
# .       .
# .   A o .
# .       .
# .........
# .........
# .       .
# .    Ao .
# .       .
# .........
# .........
# .       .
# .     A .
# .       .
# .........
# Episode:32 Total Step:8, Total Reward:100
#
#
#
#
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .    A  .
# .     o .
# .       .
# .........
# .........
# .     A .
# .     o .
# .       .
# .........
# .........
# .       .
# .     A .
# .       .
# .........
# Episode:33 Total Step:6, Total Reward:100
#
#
#
#
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .    A  .
# .     o .
# .       .
# .........
# .........
# .     A .
# .     o .
# .       .
# .........
# .........
# .       .
# .     A .
# .       .
# .........
# Episode:34 Total Step:6, Total Reward:100
#
#
#
#
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .    A  .
# .     o .
# .       .
# .........
# .........
# .     A .
# .     o .
# .       .
# .........
# .........
# .       .
# .     A .
# .       .
# .........
# Episode:35 Total Step:6, Total Reward:100
#
#
#
#
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .    A  .
# .     o .
# .       .
# .........
# .........
# .     A .
# .     o .
# .       .
# .........
# .........
# .       .
# .     A .
# .       .
# .........
# Episode:36 Total Step:6, Total Reward:100
#
#
#
#
# Episode:36 Total Step:6, Total Reward:100
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-29-e2fd17be158c> in <module>()
#      40             else:
#      41                 output_list[line_num] = ''
# ---> 42         time.sleep(2)
#
# KeyboardInterrupt:
