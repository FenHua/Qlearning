# %%
from __future__ import print_function
import copy
MAP = \
    '''
.........
.       .
.     o .
.       .
.........
'''

# MAP = \
#     '''
# .........
# .  x    .
# .   x o .
# .       .
# .........
# '''MAP= \
# 删除字符串开始和结尾
MAP=MAP.strip().split('\n')
MAP=[[c for c in line] for line in MAP]
DX=[-1,1,0,0]
DY=[0,0,-1,1]
class Env(object):
    def __init__(self):
        self.map=copy.deepcopy(MAP)
        self.x=1
        self.y=1
        self.step=0
        self.total_reward=0
        self.is_end=False
    def interact(self,action):
        assert self.is_end is False
        new_x=self.x+DX[action]
        new_y = self.y + DY[action]
        new_pos_char=self.map[new_x][new_y]
        if new_pos_char=='.':
            reward=0
        elif new_pos_char==' ':
            self.x=new_x
            self.y=new_y
            reward=0
        elif new_pos_char=='o':
            self.x = new_x
            self.y = new_y
            self.map[new_x][new_y] = ' '  # update map
            self.is_end = True  # end
            reward = 100
        elif new_pos_char=='x':
            self.x=new_x
            self.y=new_y
            self.map[new_x][new_y]=' '
            reward=-5
        self.total_reward+=reward
        return reward
    @property
    def state_num(self):
        rows = len(self.map)
        cols = len(self.map[0])
        return rows * cols
    @property
    def present_state(self):
        cols=len(self.map[0])
        return self.x*cols+self.y
    def print_map(self):
        printed_map=copy.deepcopy(self.map)
        printed_map[self.x][self.y]='A'
        print('\n'.join([''.join([c for c in line]) for line in printed_map]))
    def print_map_with_reprint(self,output_list):
        printed_map=copy.deepcopy(self.map)
        printed_map[self.x][self.y]='A'
        printed_list=[''.join([c for c in line])for line in printed_map]
        for i, line in enumerate(printed_list):
            output_list[i]=line

# %%
import numpy as np
import time

EPSILON=0.1
ALPHA=0.1
GAMMA=0.9
MAX_STEP=50

np.random.seed(1)
def epsilon_greedy(Q,state):
    if(np.random.uniform()>1-EPSILON) or ((Q[state,:]==0).all()):
        action=np.random.randint(0,4)
    else:
        action=Q[state,:].argmax()
    return action
e=Env()
Q=np.zeros((e.state_num,4))
for i in range(200):
    e=Env()
    action=epsilon_greedy(Q,e.present_state)
    while(e.is_end is False)and(e.step<MAX_STEP):
        state=e.present_state
        reward=e.interact(action)
        new_state=e.present_state
        new_action=epsilon_greedy(Q,e.present_state)
        Q[state,action]=(1-ALPHA)*Q[state,action]+\
                         ALPHA*(reward+GAMMA*Q[new_state,new_action])
        action=new_action
        e.print_map()
        time.sleep(0.1)
    print('Episode:', i, 'Total Step:', e.step, 'Total Reward:', e.total_reward)
    time.sleep(2)
# Out:
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# .       .
# .     o .
# . A     .
# .........
# .........
# .       .
# .     o .
# . A     .
# .........
# .........
# .       .
# .     o .
# . A     .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# .       .
# .     o .
# . A     .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# .       .
# .     o .
# . A     .
# .........
# .........
# .       .
# .     o .
# .  A    .
# .........
# .........
# .       .
# .     o .
# .  A    .
# .........
# .........
# .       .
# .  A  o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .    A  .
# .     o .
# .       .
# .........
# .........
# .       .
# .    Ao .
# .       .
# .........
# .........
# .    A  .
# .     o .
# .       .
# .........
# .........
# .     A .
# .     o .
# .       .
# .........
# .........
# .     A .
# .     o .
# .       .
# .........
# .........
# .      A.
# .     o .
# .       .
# .........
# .........
# .      A.
# .     o .
# .       .
# .........
# .........
# .       .
# .     oA.
# .       .
# .........
# .........
# .       .
# .     oA.
# .       .
# .........
# .........
# .       .
# .     o .
# .      A.
# .........
# .........
# .       .
# .     o .
# .      A.
# .........
# .........
# .       .
# .     o .
# .     A .
# .........
# .........
# .       .
# .     A .
# .       .
# .........
# Episode: 0 Total Step: 0 Total Reward: 100
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .       .
# .  A  o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .    A  .
# .     o .
# .       .
# .........
# .........
# .    A  .
# .     o .
# .       .
# .........
# .........
# .    A  .
# .     o .
# .       .
# .........
# .........
# .       .
# .    Ao .
# .       .
# .........
# .........
# .    A  .
# .     o .
# .       .
# .........
# .........
# .       .
# .    Ao .
# .       .
# .........
# .........
# .    A  .
# .     o .
# .       .
# .........
# .........
# .    A  .
# .     o .
# .       .
# .........
# .........
# .    A  .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# .       .
# .  A  o .
# .       .
# .........
# .........
# .       .
# .     o .
# .  A    .
# .........
# .........
# .       .
# .     o .
# .  A    .
# .........
# .........
# .       .
# .     o .
# .  A    .
# .........
# .........
# .       .
# .  A  o .
# .       .
# .........
# .........
# .       .
# .     o .
# .  A    .
# .........
# .........
# .       .
# .     o .
# .  A    .
# .........
# .........
# .       .
# .     o .
# .  A    .
# .........
# .........
# .       .
# .  A  o .
# .       .
# .........
# .........
# .       .
# .   A o .
# .       .
# .........
# .........
# .       .
# .  A  o .
# .       .
# .........
# .........
# .       .
# .     o .
# .  A    .
# .........
# .........
# .       .
# .     o .
# .   A   .
# .........
# .........
# .       .
# .     o .
# .   A   .
# .........
# .........
# .       .
# .     o .
# .    A  .
# .........
# .........
# .       .
# .    Ao .
# .       .
# .........
# .........
# .       .
# .     A .
# .       .
# .........
# Episode: 1 Total Step: 0 Total Reward: 100
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .     o .
# . A     .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .     o .
# . A     .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .     o .
# . A     .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# .       .
# .     o .
# . A     .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .     o .
# . A     .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# .       .
# .     o .
# . A     .
# .........
# .........
# .       .
# .     o .
# .  A    .
# .........
# .........
# .       .
# .  A  o .
# .       .
# .........
# .........
# .       .
# .   A o .
# .       .
# .........
# .........
# .       .
# .  A  o .
# .       .
# .........
# .........
# .       .
# .     o .
# .  A    .
# .........
# .........
# .       .
# .     o .
# .  A    .
# .........
# .........
# .       .
# .     o .
# . A     .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# .       .
# .  A  o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .       .
# .  A  o .
# .       .
# .........
# .........
# .       .
# .     o .
# .  A    .
# .........
# .........
# .       .
# .  A  o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .    A  .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .    A  .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# .       .
# .     o .
# . A     .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .     o .
# . A     .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .     o .
# . A     .
# .........
# .........
# .       .
# .     o .
# . A     .
# .........
# .........
# .       .
# .     o .
# .  A    .
# .........
# .........
# .       .
# .     o .
# . A     .
# .........
# .........
# .       .
# .     o .
# .  A    .
# .........
# .........
# .       .
# .     o .
# . A     .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .     o .
# . A     .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# .       .
# .  A  o .
# .       .
# .........
# .........
# .       .
# .   A o .
# .       .
# .........
# .........
# .       .
# .  A  o .
# .       .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# .       .
# .  A  o .
# .       .
# .........
# .........
# .       .
# .     o .
# .  A    .
# .........
# .........
# .       .
# .     o .
# . A     .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .     o .
# . A     .
# .........
# .........
# .       .
# .     o .
# . A     .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .       .
# .  A  o .
# .       .
# .........
# .........
# .       .
# .   A o .
# .       .
# .........
# .........
# .       .
# .  A  o .
# .       .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .     o .
# . A     .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# .       .
# .  A  o .
# .       .
# .........
# .........
# .       .
# .     o .
# .  A    .
# .........
# .........
# .       .
# .     o .
# .   A   .
# .........
# .........
# .       .
# .     o .
# .  A    .
# .........
# .........
# .       .
# .     o .
# .  A    .
# .........
# .........
# .       .
# .     o .
# .   A   .
# .........
# .........
# .       .
# .     o .
# .    A  .
# .........
# .........
# .       .
# .    Ao .
# .       .
# .........
# .........
# .       .
# .     A .
# .       .
# .........
# Episode: 2 Total Step: 0 Total Reward: 100
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# .       .
# .  A  o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .       .
# .  A  o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .       .
# .  A  o .
# .       .
# .........
# .........
# .       .
# .     o .
# .  A    .
# .........
# .........
# .       .
# .     o .
# .   A   .
# .........
# .........
# .       .
# .     o .
# .    A  .
# .........
# .........
# .       .
# .    Ao .
# .       .
# .........
# .........
# .       .
# .     A .
# .       .
# .........
# Episode: 3 Total Step: 0 Total Reward: 100
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# .       .
# .  A  o .
# .       .
# .........
# .........
# .       .
# .     o .
# .  A    .
# .........
# .........
# .       .
# .     o .
# .  A    .
# .........
# .........
# .       .
# .  A  o .
# .       .
# .........
# .........
# .       .
# .   A o .
# .       .
# .........
# .........
# .       .
# .    Ao .
# .       .
# .........
# .........
# .       .
# .     A .
# .       .
# .........
# Episode: 4 Total Step: 0 Total Reward: 100
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .     o .
# . A     .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# .       .
# .     o .
# . A     .
# .........
# .........
# .       .
# .     o .
# . A     .
# .........
# .........
# .       .
# .     o .
# .  A    .
# .........
# .........
# .       .
# .  A  o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .       .
# .  A  o .
# .       .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .   A   .
# .     o .
# .       .
# .........
# .........
# .       .
# .   A o .
# .       .
# .........
# .........
# .       .
# .    Ao .
# .       .
# .........
# .........
# .       .
# .     A .
# .       .
# .........
# Episode: 5 Total Step: 0 Total Reward: 100
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .     o .
# . A     .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .       .
# .  A  o .
# .       .
# .........
# .........
# .       .
# .     o .
# .  A    .
# .........
# .........
# .       .
# .     o .
# .  A    .
# .........
# .........
# .       .
# .     o .
# . A     .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# .       .
# .  A  o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .       .
# .  A  o .
# .       .
# .........
# .........
# .       .
# .   A o .
# .       .
# .........
# .........
# .       .
# .    Ao .
# .       .
# .........
# .........
# .       .
# .     A .
# .       .
# .........
# Episode: 6 Total Step: 0 Total Reward: 100
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# .       .
# .  A  o .
# .       .
# .........
# .........
# .       .
# .   A o .
# .       .
# .........
# .........
# .       .
# .    Ao .
# .       .
# .........
# .........
# .       .
# .     A .
# .       .
# .........
# Episode: 7 Total Step: 0 Total Reward: 100
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# .........
# .  A    .
# .     o .
# .       .
# .........
# .........
# .       .
# .  A  o .
# .       .
# .........
# .........
# .       .
# .   A o .
# .       .
# .........
# .........
# .       .
# .    Ao .
# .       .
# .........
# .........
# .       .
# .     A .
# .       .
# .........
# Episode: 8 Total Step: 0 Total Reward: 100
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .     o .
# . A     .
# .........
# .........
# .       .
# .     o .
# .  A    .
# .........
# .........
# .       .
# .  A  o .
# .       .
# .........
# .........
# .       .
# .   A o .
# .       .
# .........
# .........
# .       .
# .    Ao .
# .       .
# .........
# .........
# .       .
# .     A .
# .       .
# .........
# Episode: 9 Total Step: 0 Total Reward: 100
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# .A    o .
# .       .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .     o .
# . A     .
# .........
# .........
# .       .
# .     o .
# .A      .
# .........
# .........
# .       .
# .     o .
# . A     .
# .........
# .........
# .       .
# .     o .
# . A     .
# .........
# .........
# .       .
# . A   o .
# .       .
# .........
# .........
# .       .
# .  A  o .
# .       .
# .........
# .........
# .       .
# .   A o .
# .       .
# .........
# .........
# .       .
# .    Ao .
# .       .
# .........
# .........
# .       .
# .     A .
# .       .
# .........
# Episode: 10 Total Step: 0 Total Reward: 100
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# .A      .
# .     o .
# .       .
# .........
# .........
# . A     .
# .     o .
# .       .
# .........
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-206b9b99d231> in <module>()
#      27         action=new_action
#      28         e.print_map()
# ---> 29         time.sleep(0.1)
#      30     print('Episode:', i, 'Total Step:', e.step, 'Total Reward:', e.total_reward)
#      31     time.sleep(2)
#
# KeyboardInterrupt:
